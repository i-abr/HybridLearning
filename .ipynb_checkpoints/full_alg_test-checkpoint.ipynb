# %%
import math
import random

import gym
from custom_cartpoleswingup import CartPoleSwingUpEnv
import numpy as np

import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torch.distributions import Normal

from sac import SoftActorCritic
from sac import PolicyNetwork
from model_learning import ModelOptim, Model
from mppi import MPPI

# %%
from IPython.display import clear_output
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
class ReplayBuffer:
    def __init__(self, capacity):
        self.capacity = capacity
        self.buffer = []
        self.position = 0
    
    def push(self, state, action, reward, next_state, done):
        if len(self.buffer) < self.capacity:
            self.buffer.append(None)
        self.buffer[self.position] = (state, action, reward, next_state, done)
        self.position = (self.position + 1) % self.capacity
    
    def sample(self, batch_size):
        batch = random.sample(self.buffer, batch_size)
        state, action, reward, next_state, done = map(np.stack, zip(*batch))
        return state, action, reward, next_state, done
    
    def __len__(self):
        return len(self.buffer)

# %%
def plot(frame_idx, rewards):
    plt.figure(figsize=(20,5))
    plt.subplot(131)
    plt.title('frame %s. reward: %s' % (frame_idx, rewards[-1]))
    plt.plot(rewards)
    plt.show()

# %%
# env = gym.make("LunarLanderContinuous-v2")
# env = CartPoleSwingUpEnv()
env = gym.make("Pendulum-v0")

action_dim = env.action_space.shape[0]
state_dim  = env.observation_space.shape[0]
hidden_dim = 128

policy_net = PolicyNetwork(state_dim, action_dim, hidden_dim)

replay_buffer_size = 1000000
replay_buffer = ReplayBuffer(replay_buffer_size)

sac = SoftActorCritic(policy=policy_net, 
                      state_dim=state_dim, 
                      action_dim=action_dim, 
                      replay_buffer=replay_buffer)

model = Model(state_dim, action_dim)
model_optim = ModelOptim(model, replay_buffer, lr=1e-2)

planner = MPPI(model, policy_net)

# %%
max_frames  = 40000
max_steps   = 500
frame_idx   = 0
rewards     = []
batch_size  = 128

# %%
max_frames  = 40000

# %%
while frame_idx < max_frames:
    state = env.reset()
    episode_reward = 0
    
    for step in range(max_steps):
#         action = policy_net.get_action(state)
        action = planner(state)
        next_state, reward, done, _ = env.step(action)
        
        replay_buffer.push(state, action, reward, next_state, done)
        if len(replay_buffer) > batch_size:
            sac.soft_q_update(batch_size)
        
        state = next_state
        episode_reward += reward
        frame_idx += 1
        
        env.render()
        
        if frame_idx % 1000 == 0:
            clear_output(True)

            plot(frame_idx, rewards)
#             plot(frame_idx, model_optim.log['loss'])
        
        if done:
            break
    if len(replay_buffer) > 128:
        model_optim.update_model(128, mini_iter=10)

        
    rewards.append(episode_reward)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-e0b3cbb9a069> in <module>
#       5     for step in range(max_steps):
#       6 #         action = policy_net.get_action(state)
# ----> 7         action = planner(state)
#       8         next_state, reward, done, _ = env.step(action)
#       9
#
# ~/sand_box/research-projects/SMPO/mppi.py in __call__(self, state)
#      37                 log_prob.append(pi.log_prob(self.a[t]).sum(1))
#      38                 da.append(v - self.a[t])
# ---> 39                 s_dist, rew = self.model(s, v)
#      40                 s = s_dist.mean
#      41                 mu, log_std = self.policy(s)
#
# ~/.local/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     539             result = self._slow_forward(*input, **kwargs)
#     540         else:
# --> 541             result = self.forward(*input, **kwargs)
#     542         for hook in self._forward_hooks.values():
#     543             hook_result = hook(self, input, result)
#
# ~/sand_box/research-projects/SMPO/model_learning/model.py in forward(self, s, a)
#      41         for i in self.n_params[:-1]:
#      42             w = getattr(self, 'layer' + str(i))
# ---> 43             x = w(x)
#      44             x = F.relu(x)
#      45             # x = torch.sin(x)
#
# ~/.local/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     540         else:
#     541             result = self.forward(*input, **kwargs)
# --> 542         for hook in self._forward_hooks.values():
#     543             hook_result = hook(self, input, result)
#     544             if hook_result is not None:
#
# KeyboardInterrupt:

# %%
model_optim = ModelOptim(model, replay_buffer, lr=1e-5)

# %%
model_optim.update_model(256, mini_iter=500)

# %%
plot(frame_idx, model_optim.log['loss'])

# %%
plt.plot(rewards)

# %%
60*500
# Out:
# 30000
