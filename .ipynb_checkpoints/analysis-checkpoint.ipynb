# %%
import pickle
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pickle.load(open('./benchmark_examples/data/pend_swingup/reward_data.pkl', 'rb'))
data2 = pickle.load(open('./examples/data/pend_swingup/reward_data2.pkl', 'rb'))

# %%
plt.plot(data)
plt.plot(data2, 'r')

# %%
data = pickle.load(open('./benchmark_examples/data/lunar_lander/reward_data.pkl', 'rb'))
data2 = pickle.load(open('./examples/data/lunar_lander/reward_data.pkl', 'rb'))

# %%
plt.plot(data)
plt.plot(data2, 'r')

# %%
len(data)
# Out:
# 13

# %%
len(data2)
# Out:
# 44

# %%
import numpy as np

# %%
d1 = np.random.normal(np.array([1., 1.]), 0.4, size=(100,2))
d2 = np.random.normal(np.array([-1., -1.]), 0.4, size=(100,2))

# %%
data_set = np.concatenate([d1, d2], axis=0)

# %%
plt.scatter(data_set[:,0], data_set[:,1])

# %%
import scipy

# %%
import scipy.linalg as la

# %%
la.pinv2()
