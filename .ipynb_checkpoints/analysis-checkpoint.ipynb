# %%
import pickle
import numpy as np
import matplotlib.pyplot as plt
import glob

# %%
def process_data(env_path):
    data = []
    min_size = np.inf
    for path in glob.glob(env_path + '*/'):
        data_set = pickle.load(open(path + 'reward_data.pkl', 'rb'))
        data_set = np.stack(data_set)
        if data_set[-1,0] < min_size:
            min_size = data_set[-1,0]
        data.append(data_set)
    x_samples = np.linspace(0, min_size)
    interp_data = []
    for data_set in data:
        _x = data_set[:,0]
        _y = data_set[:,1]
        interp_data.append(np.interp(x_samples, _x, _y))
    
#     data = np.stack([d[:min_size] for d in data])
    mean = np.mean(interp_data, axis=0)
    std  = np.std(interp_data, axis=0)
    data_log = {'x' : x_samples, 'mean' : mean, 'std' : std}
    return data_log

def plot_data(log, label):
    plt.plot(log['x'], log['mean'], label=label)
    plt.fill_between(log['x'], 
                    log['mean']-log['std']*0.95, log['mean']+log['std']*0.95,
                    alpha=0.2)

# %%
ddpg_data
# Out:
# {'x': array([   0.        ,  122.44897959,  244.89795918,  367.34693878,
#          489.79591837,  612.24489796,  734.69387755,  857.14285714,
#          979.59183673, 1102.04081633, 1224.48979592, 1346.93877551,
#         1469.3877551 , 1591.83673469, 1714.28571429, 1836.73469388,
#         1959.18367347, 2081.63265306, 2204.08163265, 2326.53061224,
#         2448.97959184, 2571.42857143, 2693.87755102, 2816.32653061,
#         2938.7755102 , 3061.2244898 , 3183.67346939, 3306.12244898,
#         3428.57142857, 3551.02040816, 3673.46938776, 3795.91836735,
#         3918.36734694, 4040.81632653, 4163.26530612, 4285.71428571,
#         4408.16326531, 4530.6122449 , 4653.06122449, 4775.51020408,
#         4897.95918367, 5020.40816327, 5142.85714286, 5265.30612245,
#         5387.75510204, 5510.20408163, 5632.65306122, 5755.10204082,
#         5877.55102041, 6000.        ]),
#  'mean': array([-1278.25171636, -1278.25171636, -1348.62963834, -1540.56942557,
#         -1476.07271743, -1304.47922184, -1008.26135133,  -820.95382614,
#          -758.11526706,  -688.29324708,  -600.551155  ,  -446.71554322,
#          -308.52022707,  -182.28513699,  -135.18120374,  -103.32767327,
#           -93.86988981,   -89.85451922,   -88.5056309 ,   -85.56974216,
#           -84.59527692,   -86.56294694,   -86.05766932,   -83.86246111,
#           -75.57483958,   -76.15560136,   -85.60474645,   -87.57805793,
#           -85.90758628,   -76.04367719,   -79.47758372,   -91.77670067,
#           -88.69292484,   -93.64610955,  -115.7341045 ,  -107.54270968,
#           -87.85487548,   -88.89322851,   -88.78807477,   -87.18756602,
#           -79.84037761,   -74.08660272,   -83.48324505,   -84.18247547,
#           -77.27147047,   -74.58079864,   -72.59880201,   -71.27611591,
#           -71.89261914,   -73.63181094]),
#  'std': array([5.57473744e+01, 5.57473744e+01, 3.84627039e+01, 8.67730662e+00,
#         2.09365760e+01, 1.45481245e+01, 4.55146629e+01, 7.79443380e+01,
#         7.87933136e+01, 8.44057034e+01, 1.05927904e+02, 1.87278615e+02,
#         1.63829014e+02, 6.02379977e+01, 3.26992723e+01, 1.43312906e+01,
#         4.68632929e+00, 1.46347755e+00, 1.41280856e+00, 2.34850816e-01,
#         7.74798687e-01, 1.53198583e+00, 1.65835149e+00, 4.66521145e-01,
#         8.04565373e+00, 8.20246680e+00, 3.91807173e-03, 5.64070567e-01,
#         1.75606322e+00, 9.70853592e+00, 8.07233662e+00, 4.36893368e-02,
#         8.49396236e-02, 6.88584097e+00, 2.75761160e+01, 2.05056882e+01,
#         2.64293754e+00, 2.51882676e-01, 1.04093851e+00, 8.97607967e-01,
#         6.76134952e+00, 1.16595724e+01, 4.22136173e+00, 5.22007274e+00,
#         1.64143280e+01, 1.57171606e+01, 9.93632342e+00, 6.19111510e+00,
#         1.91288003e+00, 1.41791661e+01])}

# %%
hddpg_data = process_data('./benchmarks/data/PendulumEnv/h_ddpg/')
ddpg_data = process_data('./benchmarks/data/PendulumEnv/ddpg/')


plot_data(ddpg_data, 'DDPG')
plot_data(hddpg_data, 'H-DDPG')

plt.xlabel('time steps')
plt.ylabel('episode total reward')
plt.title('Pendulum Swingup')

plt.legend()

# %%
hddpg_data = process_data('./benchmarks/data/PendulumEnv/h_ddpg/')
ddpg_data = process_data('./benchmarks/data/PendulumEnv/ddpg/')


plot_data(ddpg_data, 'DDPG')
plot_data(hddpg_data, 'H-DDPG')

plt.xlabel('time steps')
plt.ylabel('episode total reward')
plt.title('Pendulum Swingup')

plt.legend()

# %%
hybrid_data = process_data('./examples/sac/data/InvertedPendulumSwingupBulletEnv/')
sac_data = process_data('./benchmark_examples/sac/data/InvertedPendulumSwingupBulletEnv/')

# hddpg_data = process_data('./examples/ddpg/data/InvertedPendulumSwingupBulletEnv/')
# ddpg_data = process_data('./benchmark_examples/ddpg/data/InvertedPendulumSwingupBulletEnv/')

plot_data(sac_data, 'SAC')
plot_data(hybrid_data, 'H-SAC')

# plot_data(ddpg_data, 'DDPG', 'b')
# plot_data(hddpg_data, 'H-DDPG', 'r')

plt.xlabel('time steps')
plt.ylabel('episode total reward')
plt.title('Cart Pendulum Swingup')

plt.legend()

# %%
# hddpg_data = process_data('./examples/ddpg/data/LunarLanderContinuousEnv/')
# ddpg_data = process_data('./benchmark_examples/ddpg/data/LunarLanderContinuousEnv/')

# plot_data(ddpg_data, 'DDPG', 'b')
# plot_data(hddpg_data, 'H-DDPG', 'r')

hddpg_data = process_data('./examples/sac/data/LunarLanderContinuousEnv/')
ddpg_data = process_data('./benchmark_examples/sac/data/LunarLanderContinuousEnv/')

plot_data(ddpg_data, 'SAC')
plot_data(hddpg_data, 'H-SAC')

# plt.plot(sac_data[1][:,0], sac_data[1][:,1])

# plt.plot(hybrid_data[1][:,0], hybrid_data[1][:,1])

plt.xlabel('episodes')
plt.ylabel('episode total reward')
plt.title('Lunar Lander')

plt.ylim(-300, 100)
plt.legend()

# %%
hybrid_data = process_data('./examples/data/HopperBulletEnv/')
sac_data = process_data('./benchmark_examples/data/HopperBulletEnv/')

plot_data(sac_data, 'SAC', 'b')
plot_data(hybrid_data, 'H-SAC', 'r')

# plt.plot(hybrid_data[0].T)

plt.xlabel('time steps')
plt.ylabel('episode total reward')
plt.title('Hopper Env')

plt.legend()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-182-eafcdf5f1880> in <module>
#       2 sac_data = process_data('./benchmark_examples/data/HopperBulletEnv/')
#       3
# ----> 4 plot_data(sac_data, 'SAC', 'b')
#       5 plot_data(hybrid_data, 'H-SAC', 'r')
#       6
#
# TypeError: plot_data() takes 2 positional arguments but 3 were given
