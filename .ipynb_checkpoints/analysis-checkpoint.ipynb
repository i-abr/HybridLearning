# %%
import pickle
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pickle.load(open('./benchmark_examples/rew_data.pkl', 'rb'))
data2 = pickle.load(open('./examples/rew_data.pkl', 'rb'))

# %%
plt.plot(data)
plt.plot(data2)
