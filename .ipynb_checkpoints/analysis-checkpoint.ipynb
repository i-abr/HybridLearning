# %%
import pickle
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pickle.load(open('./benchmark_examples/data/pend_swingup/reward_data.pkl', 'rb'))
data2 = pickle.load(open('./examples/data/pend_swingup/reward_data3.pkl', 'rb'))

# %%
plt.plot(data, label='Soft Actor Critic')
plt.plot(data2, label='Hybrid Control Soft Actor Critic')
plt.xlabel('episodes')
plt.ylabel('episode total reward')
plt.title('Pendulum swingup task')

plt.legend()

plt.savefig('pend_swingup.png')

# %%
data = pickle.load(open('./benchmark_examples/data/pend_swingup/reward_data2.pkl', 'rb'))
data2 = pickle.load(open('./examples/data/pend_swingup/reward_data3.pkl', 'rb'))

# %%
plt.plot(data, label='Soft Actor Critic')
plt.plot(data2, label='Hybrid Control Soft Actor Critic')
plt.xlabel('episodes')
plt.ylabel('episode total reward')
plt.title('Pendulum swingup task')

plt.legend()

plt.savefig('pend_swingup.png')

# %%
data = pickle.load(open('./benchmark_examples/data/InvertedPendulumSwingupBulletEnv-v0/reward_data.pkl', 'rb'))
data2 = pickle.load(open('./examples/data/InvertedPendulumSwingupBulletEnv-v0/reward_data.pkl', 'rb'))

# %%
plt.plot(data, label='Soft Actor Critic')
plt.plot(data2, label='Hybrid Control Soft Actor Critic')
plt.xlabel('episodes')
plt.ylabel('episode total reward')
plt.title('Lunar Lander')

plt.legend()

plt.savefig('lunar_lander.png')

# %%
data = pickle.load(open('./benchmark_examples/data/lunar_lander/reward_data4.pkl', 'rb'))
data2 = pickle.load(open('./examples/data/lunar_lander/reward_data4.pkl', 'rb'))

# %%
plt.plot(data, label='Soft Actor Critic')
plt.plot(data2, label='Hybrid Control Soft Actor Critic')
plt.ylabel('episode total reward')
plt.title('Lunar Lander')

plt.legend()

plt.savefig('lunar_lander.png')

# %%
# data = pickle.load(open('./benchmark_examples/data/lunar_lander/reward_data.pkl', 'rb'))
data2 = pickle.load(open('./examples/data/HalfCheetahBulletEnv-v0/reward_data.pkl', 'rb'))

# %%
# plt.plot(data, label='Soft Actor Critic')
plt.plot(data2, label='Hybrid Control Soft Actor Critic')
plt.ylabel('episode total reward')
plt.title('Lunar Lander')

plt.legend()

# plt.savefig('lunar_lander.png')

# %%
400*500
# Out:
# 200000

# %% [markdown]
# $$x_{t+1} = f(x_t, u_t)$$
# $$
#     \frac{\partial x_{t+1}} { \partial x_t} = f(x_t, u_t) + \nabla f
# $$

# %%
import numpy as np

# %%
def f(x):
    return x + 0.01*np.array([x[1], -9.81 * np.sin(x[0])-0.1*x[1]])

# %%
f(np.array([0., 0.1]))
# Out:
# array([0.001 , 0.0999])
