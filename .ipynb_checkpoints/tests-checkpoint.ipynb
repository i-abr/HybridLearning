# %%
import numpy as np
# from cart_pole_env import CartPoleSwingUpEnv
# from cart_pole_model import CartPoleModel
from custom_cartpoleswingup import CartPoleSwingUpEnv
import matplotlib.pyplot as plt
from IPython.display import clear_output

# %%
class IndirectController(object):

    def __init__(self, model, task, T=20):
        self.T = T
        self.nu = model.action_space.shape[0]
        self.nx = model.observation_space.shape[0]
        self.u = [np.random.normal(0., 0.1, size=(self.nu,)) for t in range(T-1)]
        
        self.model = model
        self.task  = task
        
    def __call__(self, state):
        
        self.u[:-1] = self.u[1:]
        self.u[-1]  = np.zeros(self.nu)
        
        self.model.set_state(state)
        A = []
        B = []
        ldx = []
        ldu = []
        for t in range(self.T-1):
            ldx_t = self.task.ldx(self.model.state)
            ldu_t = self.task.ldu(self.u[t])
            
            self.model.step(self.u[t])
            A_t = self.model.A
            B_t = self.model.B

            A.append(A_t)
            B.append(B_t)
            ldx.append(ldx_t)
            ldu.append(ldu_t)
        
        _rho = []
        rho = np.zeros(self.nx)
        for t in reversed(range(self.T-1)):
            rho = np.dot(A[t].T, rho) + ldx[t]
            self.u[t] = -np.dot(B[t].T, rho) + self.u[t]
            _rho.append(rho.copy())
#         clear_output(wait=True)
#         plt.plot(_rho)
#         plt.pause(0.01)
        return self.u[0].copy()

# %%
env = CartPoleSwingUpEnv()
task = env.task

# %%
model = CartPoleSwingUpEnv()
controller = IndirectController(model, task, T=50)

# %%
state = env.reset()
actions = []
log = {
    'states' : [],
    'next_states' : [],
    'actions' : []
}
for _ in range(800):
    action = np.random.normal(0.,4.0, size=(1,))
    next_state = env.step(action)
    env.render()
    log['states'].append(state.copy())
    log['next_states'].append(next_state.copy())
    log['actions'].append(action.copy())
    
    state = next_state
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-62-85bfdfb82582> in <module>
#       9     action = np.random.normal(0.,4.0, size=(1,))
#      10     next_state = env.step(action)
# ---> 11     env.render()
#      12     log['states'].append(state.copy())
#      13     log['next_states'].append(next_state.copy())
#
# ~/sand_box/research-projects/SMPO/custom_cartpoleswingup.py in render(self, mode, close)
#     203         self.pole_bob_trans.set_translation(-self.l*np.sin(x[0]), self.l*np.cos(x[0]))
#     204
# --> 205         return self.viewer.render(return_rgb_array = mode=='rgb_array')
#
# ~/.local/lib/python3.6/site-packages/gym/envs/classic_control/rendering.py in render(self, return_rgb_array)
#      90     def render(self, return_rgb_array=False):
#      91         glClearColor(1,1,1,1)
# ---> 92         self.window.clear()
#      93         self.window.switch_to()
#      94         self.window.dispatch_events()
#
# ~/.local/lib/python3.6/site-packages/pyglet/window/__init__.py in clear(self)
#    1226         buffer.  The window must be the active context (see `switch_to`).
#    1227         """
# -> 1228         gl.glClear(gl.GL_COLOR_BUFFER_BIT | gl.GL_DEPTH_BUFFER_BIT)
#    1229
#    1230     def dispatch_event(self, *args):
#
# ~/.local/lib/python3.6/site-packages/pyglet/gl/lib.py in errcheck(result, func, arguments)
#      83     pass
#      84
# ---> 85 def errcheck(result, func, arguments):
#      86     if _debug_gl_trace:
#      87         try:
#
# KeyboardInterrupt:

# %%
actions = np.stack(log['actions'])

# %%
plt.plot(actions)
# plt.ylim(-1,1)

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

# %%
class Model(nn.Module):
    
    def __init__(self, nx, nu, H=32):
        super(Model, self).__init__()
        self.linear1 = torch.nn.Linear(nx + nu, H)
        self.linear2 = torch.nn.Linear(H, nx)

    def forward(self, x, u):
        s = torch.cat([x, u], axis=1)
        h_relu = torch.sin(self.linear1(s))
        y_pred = self.linear2(h_relu)
        return y_pred

# %%
model = Model(env.observation_space.shape[0], env.action_space.shape[0])

# %%
optimizer = optim.Adam(model.parameters(), lr=1e-3)

# %%
states = torch.FloatTensor(np.stack(log['states']))
next_states = torch.FloatTensor(np.stack(log['next_states']))
actions = torch.FloatTensor(np.stack(log['actions']))

# %%
for i in range(200):
    
    pred_states = states + model(states, actions)
    loss = 0.5 * torch.mean(torch.pow(next_states-pred_states,2))
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()
    
    clear_output(wait=True)
    print('iter ', i)
    plt.plot(pred_states.data.numpy(),'r')
    plt.plot(next_states.data.numpy(),'k')
    plt.pause(0.1)
# Out:
# iter  51
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-75-1d79c455cf74> in <module>
#      12     plt.plot(pred_states.data.numpy(),'r')
#      13     plt.plot(next_states.data.numpy(),'k')
# ---> 14     plt.pause(0.1)
#
# ~/.local/lib/python3.6/site-packages/matplotlib/pyplot.py in pause(interval)
#     293             canvas.draw_idle()
#     294         show(block=False)
# --> 295         canvas.start_event_loop(interval)
#     296     else:
#     297         time.sleep(interval)
#
# ~/.local/lib/python3.6/site-packages/matplotlib/backend_bases.py in start_event_loop(self, timeout)
#    2250         while self._looping and counter * timestep < timeout:
#    2251             self.flush_events()
# -> 2252             time.sleep(timestep)
#    2253             counter += 1
#    2254
#
# KeyboardInterrupt:
