# %%
import pickle
import numpy as np
import matplotlib.pyplot as plt
import glob
import seaborn as sns
sns.set(style="dark")
plt.rcParams.update({'font.size': 8})

# %%
data = pickle.load(open('./sawyer/h_sac/2020-02-04_13-05-20/reward_data.pkl', 'rb'),  encoding="bytes")

# %%
plt.plot([x[1] for x in data])

# %%
data = pickle.load(open('./sawyer/sac/2020-02-04_13-41-54/reward_data.pkl', 'rb'),  encoding="bytes")

# %%
plt.plot([x[1] for x in data])

# %%
data
# Out:
# [[500, -37.43439437690184],
#  [675, -0.17824752067185656],
#  [897, -6.140895771212502],
#  [1242, -12.144603098803106],
#  [1476, -7.355600707896478]]
